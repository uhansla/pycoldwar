# %%
from lupa import LuaRuntime
import pandas as pd
from dcs.weapons_data import Weapons
import dcs_util as dcs_util
from collections import defaultdict


# --- Step 2: Load and parse Lua mission ---

mission_data, lua = dcs_util.load_mission("Pretense_Caucasus_2.0.alpha4\\Pretense_Caucasus_2.0.alpha4\\mission")
coldwar_mission_data, lua_cold = dcs_util.load_mission("coldwar\\mission")
cold_df = dcs_util.get_planes(coldwar_mission_data)


# --- Step 5: Extract and display units ---
# df = dcs_util.get_planes(mission_data)
# df[df['Skill']!='Client']

# %%
cold_df = dcs_util.get_planes(coldwar_mission_data)
cold_df[cold_df['Skill']!='Client']
# Out:
#      Side              Group Name                Unit Name  Unit Type Skill  \
# 1    Blue         kiryat-cas-blue       kiryat-cas-red-1-1    MB-339A  Good
# 2    Blue         kiryat-cas-blue        kiryat-cas-blue-1    MB-339A  Good
# 17   Blue     ramatdavid-cas-blue               Aerial-1-1      A-10A  Good
# 18   Blue     ramatdavid-cas-blue    ramatdavid-cas-blue-1      A-10A  Good
# 19   Blue  ramatdavid-strike-blue  ramatdavid-cas-blue-1-1  F-4E-45MC  Good
# ..    ...                     ...                      ...        ...   ...
# 247   Red        tiyas-patrol-red       tiyas-patrol-red-1  MiG-21Bis  Good
# 248   Red          tiyas-sead-red      tiyas-sead-blue-1-1     Su-24M  Good
# 249   Red          tiyas-sead-red         tiyas-sead-red-1     Su-24M  Good
# 250   Red            rene-cas-red       tiyas-sead-red-1-1     Su-24M  Good
# 251   Red            rene-cas-red          rene-sead-red-1     Su-24M  Good
#
#                                  Livery ID  \
# 1                            mb339ad 'uae'
# 2                            mb339ad 'uae'
# 17   104th fs maryland ang, baltimore (md)
# 18   104th fs maryland ang, baltimore (md)
# 19                                 default
# ..                                     ...
# 247                        afghanistan (1)
# 248                       syrian air force
# 249                       syrian air force
# 250                       syrian air force
# 251                       syrian air force
#
#                                          Weapons CLSID  \
# 1    {MB339_DEFA553_R}, {LR25_ARF8M3_API}, {BCE4E03...
# 2    {MB339_DEFA553_R}, {LR25_ARF8M3_API}, {BCE4E03...
# 17   {3C0745ED-8B0B-42eb-B907-5BD5C1717447}, {69926...
# 18   {3C0745ED-8B0B-42eb-B907-5BD5C1717447}, {69926...
# 19   {HB_F4E_MK-82_6x}, {AIM-9P5}, {AIM-9P5}, {HB_F...
# ..                                                 ...
# 247  {R-3R}, {R-60 2L}, {PTB_800_MIG21}, {R-60 2R},...
# 248  {Kh-25MP}, {APU-60-1_R_60M}, {Kh-25MP}, {16602...
# 249  {Kh-25MP}, {APU-60-1_R_60M}, {Kh-25MP}, {16602...
# 250  {A0648264-4BC0-4EE8-A543-D119F6BA4257}, {APU-6...
# 251  {A0648264-4BC0-4EE8-A543-D119F6BA4257}, {APU-6...
#
#                                           Weapon Names  \
# 1    DEFA553 Gunpod Right, LR-25 - 25 x UnGd Rkts, ...
# 2    DEFA553 Gunpod Right, LR-25 - 25 x UnGd Rkts, ...
# 17   LAU-105 with 2 x AIM-9P Sidewinder IR AAM, LAU...
# 18   LAU-105 with 2 x AIM-9P Sidewinder IR AAM, LAU...
# 19   6x Mk-82 - 500lb GP Bomb LD (MER), AIM-9P5 Sid...
# ..                                                 ...
# 247  APU-13U-2 with R-3R (AA-2 Atoll-C) - Semi Acti...
# 248  Kh-25MP (AS-12 Kegler) - 320kg, ARM, Pas Rdr, ...
# 249  Kh-25MP (AS-12 Kegler) - 320kg, ARM, Pas Rdr, ...
# 250  O-25 - 1 x UnGd Rkts, 340 mm S-25-OFM Hardened...
# 251  O-25 - 1 x UnGd Rkts, 340 mm S-25-OFM Hardened...
#
#      Total Weapon Weight (kg)
# 1                     1118.00
# 2                     1118.00
# 17                    2209.96
# 18                    2209.96
# 19                    4237.40
# ..                        ...
# 247                   1246.28
# 248                   2561.00
# 249                   2561.00
# 250                   3733.00
# 251                   3733.00
#
# [237 rows x 9 columns]

# %%
pmap = dcs_util.generate_plane_templates_from_mission(coldwar_mission_data)
pmap
# Out:
# {'MB-339A': [{'type': 'MB-339A',
#    'payload': {'pylons': [None,
#      'planes.Tornado_IDS.Pylon8.Mk_82___500lb_GP_Bomb_LD',
#      'planes.MB_339A.Pylon9.LR_25___25_x_UnGd_Rkts__50_mm_ARF_8_M3_API',
#      'planes.MB_339A.Pylon4.DEFA553_Gunpod_Left',
#      None,
#      None,
#      'planes.MB_339A.Pylon7.DEFA553_Gunpod_Right',
#      'planes.MB_339A.Pylon9.LR_25___25_x_UnGd_Rkts__50_mm_ARF_8_M3_API',
#      'planes.Tornado_IDS.Pylon8.Mk_82___500lb_GP_Bomb_LD']}}],
#  'A-10A': [{'type': 'A-10A',
#    'payload': {'pylons': ['planes.A_10A.Pylon11.LAU_105_with_2_x_AIM_9P_Sidewinder_IR_AAM',
#      'planes.A_10C_2.Pylon9.LAU_131___7_x_UnGd_Rkts__70_mm_Hydra_70_M151_HE',
#      'planes.F_4E.Pylon2.LAU_88_with_2_x_AGM_65D___Maverick_D__IIR_ASM_',
#      None,
#      None,
#      None,
#      None,
#      None,
#      'planes.F_4E.Pylon8.LAU_88_with_2_x_AGM_65D___Maverick_D__IIR_ASM__',
#      'planes.A_10C_2.Pylon9.LAU_131___7_x_UnGd_Rkts__70_mm_Hydra_70_M151_HE',
#      'planes.A_10A.Pylon11.LAU_105_with_2_x_AIM_9P_Sidewinder_IR_AAM']}},
#   {'type': 'A-10A',
#    'payload': {'pylons': ['planes.A_10A.Pylon11.LAU_105_with_2_x_AIM_9P_Sidewinder_IR_AAM',
#      'planes.A_10C_2.Pylon9.LAU_131___7_x_UnGd_Rkts__70_mm_Hydra_70_M151_HE',
#      'planes.F_16C_bl_52d.Pylon3.LAU_88_AGM_65H_2_L',
#      None,
#      None,
#      None,
#      None,
#      None,
#      'planes.F_16C_bl_52d.Pylon8.LAU_88_AGM_65H_2_R',
#      'planes.A_10C_2.Pylon9.LAU_131___7_x_UnGd_Rkts__70_mm_Hydra_70_M151_HE',
#      'planes.A_10A.Pylon11.LAU_105_with_2_x_AIM_9P_Sidewinder_IR_AAM']}}],
#  'F-4E-45MC': [{'type': 'F-4E-45MC',
#    'payload': {'pylons': ['planes.F_4E_45MC.Pylon7._6x_Mk_82___500lb_GP_Bomb_LD__MER_',
#      'planes.Tornado_IDS.Pylon3.AIM_9P5_Sidewinder_IR_AAM',
#      None,
#      'planes.Tornado_IDS.Pylon3.AIM_9P5_Sidewinder_IR_AAM',
#      'planes.F_4E_45MC.Pylon9.AIM_7M',
#      'planes.F_4E_45MC.Pylon9.AIM_7M',
#      None,
#      'planes.F_4E_45MC.Pylon9.AIM_7M',
#      'planes.F_4E_45MC.Pylon9.AIM_7M',
#      'planes.Tornado_IDS.Pylon3.AIM_9P5_Sidewinder_IR_AAM',
#      None,
#      'planes.Tornado_IDS.Pylon3.AIM_9P5_Sidewinder_IR_AAM',
#      'planes.F_4E_45MC.Pylon7._6x_Mk_82___500lb_GP_Bomb_LD__MER_',
#      'planes.F_4E_45MC.Pylon14.ALE_40_Dispensers__30_Flares__60_Chaff_']}},
#   {'type': 'F-4E-45MC',
#    'payload': {'pylons': ['planes.F_4E_45MC.Pylon3.AGM_45A_Shrike_ARM__LAU_34_',
#      None,
#      'planes.F_4E_45MC.Pylon3._2x_AGM_65B___Maverick_B__TV_Guided___LAU_88__',
#      None,
#      'planes.F_4E_45MC.Pylon9.AIM_7M',
#      'planes.F_4E_45MC.Pylon9.AIM_7M',
#      None,
#      'planes.F_4E_45MC.Pylon9.AIM_7M',
#      'planes.F_4E_45MC.Pylon9.AIM_7M',
#      None,
#      'planes.F_4E_45MC.Pylon11._2x_AGM_65B___Maverick_B__TV_Guided___LAU_88_',
#      None,
#      'planes.F_4E_45MC.Pylon3.AGM_45A_Shrike_ARM__LAU_34_',
#      'planes.F_4E_45MC.Pylon14.ALE_40_Dispensers__30_Flares__60_Chaff_']}}],
#  'AJS37': [{'type': dcs.planes.AJS37,
#    'payload': {'pylons': ['planes.AJS37.Pylon7.LAU_7_with_RB_24__AIM_9B__Sidewinder_IR_AAM',
#      'planes.AJS37.Pylon6.Rb_75A__AGM_65A_Maverick___TV_ASM_',
#      'planes.AJS37.Pylon6.Rb_75A__AGM_65A_Maverick___TV_ASM_',
#      'planes.AJS37.Pylon4.AJS_External_tank_1013kg_fuel',
#      'planes.AJS37.Pylon6.Rb_75A__AGM_65A_Maverick___TV_ASM_',
#      'planes.AJS37.Pylon6.Rb_75A__AGM_65A_Maverick___TV_ASM_',
#      'planes.AJS37.Pylon7.LAU_7_with_RB_24__AIM_9B__Sidewinder_IR_AAM']}},
#   {'type': dcs.planes.AJS37,
#    'payload': {'pylons': ['planes.AJS37.Pylon7.LAU_7_with_RB_24__AIM_9B__Sidewinder_IR_AAM',
#      'planes.AJS37.Pylon6.KB_Flare_Chaff_dispenser_pod',
#      'planes.AJS37.Pylon6.Rb_75B__AGM_65B_Maverick___TV_ASM_',
#      None,
#      'planes.AJS37.Pylon6.Rb_75B__AGM_65B_Maverick___TV_ASM_',
#      'planes.AJS37.Pylon6.U_22_Jammer_pod',
#      'planes.AJS37.Pylon7.LAU_7_with_RB_24__AIM_9B__Sidewinder_IR_AAM']}},
#   {'type': dcs.planes.AJS37,
#    'payload': {'pylons': ['planes.AJS37.Pylon7.LAU_7_with_RB_24__AIM_9B__Sidewinder_IR_AAM',
#      'planes.AJS37.Pylon6._4x_SB_M_71_120kg_GP_Bomb_Low_drag',
#      'planes.AJS37.Pylon6._4x_SB_M_71_120kg_GP_Bomb_Low_drag',
#      'planes.AJS37.Pylon4.AJS_External_tank_1013kg_fuel',
#      'planes.AJS37.Pylon6._4x_SB_M_71_120kg_GP_Bomb_Low_drag',
#      'planes.AJS37.Pylon6._4x_SB_M_71_120kg_GP_Bomb_Low_drag',
#      'planes.AJS37.Pylon7.LAU_7_with_RB_24__AIM_9B__Sidewinder_IR_AAM']}},
#   {'type': dcs.planes.AJS37,
#    'payload': {'pylons': ['planes.AJS37.Pylon7.LAU_7_with_RB_24__AIM_9B__Sidewinder_IR_AAM',
#      'planes.AJS37.Pylon6.KB_Flare_Chaff_dispenser_pod',
#      'planes.AJS37.Pylon6.Rb_75B__AGM_65B_Maverick___TV_ASM_',
#      'planes.AJS37.Pylon4.AJS_External_tank_1013kg_fuel',
#      'planes.AJS37.Pylon6.Rb_75B__AGM_65B_Maverick___TV_ASM_',
#      'planes.AJS37.Pylon6.U_22_Jammer_pod',
#      'planes.AJS37.Pylon7.LAU_7_with_RB_24__AIM_9B__Sidewinder_IR_AAM']}}],
#  'Mirage-F1CE': [{'type': 'Mirage-F1CE',
#    'payload': {'pylons': ['planes.Mirage_F1M_EE.Pylon7.R550_Magic_1_IR_AAM',
#      'planes.Mirage_F1M_EE.Pylon6.SAMP_400___400_kg_GP_Bomb_LD',
#      'planes.Mirage_F1M_EE.Pylon6.SAMP_400___400_kg_GP_Bomb_LD',
#      'planes.Mirage_F1M_EE.Pylon4.CLB_4___4_x_SAMP_400___400_kg_GP_Bomb_LD',
#      'planes.Mirage_F1M_EE.Pylon6.SAMP_400___400_kg_GP_Bomb_LD',
#      'planes.Mirage_F1M_EE.Pylon6.SAMP_400___400_kg_GP_Bomb_LD',
#      'planes.Mirage_F1M_EE.Pylon7.R550_Magic_1_IR_AAM']}}],
#  'F-86F Sabre': [{'type': 'F-86F Sabre',
#    'payload': {'pylons': ['planes.F_86F_Sabre.Pylon9._2_x_HVAR__UnGd_Rkts',
#      'planes.F_86F_Sabre.Pylon9._2_x_HVAR__UnGd_Rkts',
#      'planes.F_86F_Sabre.Pylon9._2_x_HVAR__UnGd_Rkts',
#      'planes.F_86F_Sabre.Pylon9._2_x_HVAR__UnGd_Rkts',
#      'planes.F_86F_Sabre.Pylon6.LAU_7_with_AIM_9B_Sidewinder_IR_AAM',
#      'planes.F_86F_Sabre.Pylon6.LAU_7_with_AIM_9B_Sidewinder_IR_AAM',
#      'planes.F_86F_Sabre.Pylon9._2_x_HVAR__UnGd_Rkts',
#      'planes.F_86F_Sabre.Pylon9._2_x_HVAR__UnGd_Rkts',
#      'planes.F_86F_Sabre.Pylon9._2_x_HVAR__UnGd_Rkts',
#      'planes.F_86F_Sabre.Pylon9._2_x_HVAR__UnGd_Rkts']}}],
#  'F-5E-3': [{'type': 'F-5E-3',
#    'payload': {'pylons': ['planes.Tornado_IDS.Pylon3.AIM_9P_Sidewinder_IR_AAM',
#      'planes.Tornado_IDS.Pylon8.Mk_82___500lb_GP_Bomb_LD',
#      'planes.F_5E_3_FC.Pylon5.F_5_275Gal_Fuel_tank',
#      'planes.F_5E_3_FC.Pylon4._5_x_Mk_82___500lb_GP_Bombs_LD',
#      'planes.F_5E_3_FC.Pylon5.F_5_275Gal_Fuel_tank',
#      'planes.Tornado_IDS.Pylon8.Mk_82___500lb_GP_Bomb_LD',
#      'planes.Tornado_IDS.Pylon3.AIM_9P_Sidewinder_IR_AAM']}},
#   {'type': 'F-5E-3',
#    'payload': {'pylons': ['planes.Tornado_IDS.Pylon3.AIM_9P_Sidewinder_IR_AAM',
#      'planes.Tornado_IDS.Pylon8.Mk_82___500lb_GP_Bomb_LD',
#      'planes.Tornado_IDS.Pylon8.Mk_82___500lb_GP_Bomb_LD',
#      'planes.F_5E_3_FC.Pylon4._5_x_Mk_82___500lb_GP_Bombs_LD',
#      'planes.Tornado_IDS.Pylon8.Mk_82___500lb_GP_Bomb_LD',
#      'planes.Tornado_IDS.Pylon8.Mk_82___500lb_GP_Bomb_LD',
#      'planes.Tornado_IDS.Pylon3.AIM_9P_Sidewinder_IR_AAM']}},
#   {'type': 'F-5E-3',
#    'payload': {'pylons': ['planes.Tornado_IDS.Pylon3.AIM_9P_Sidewinder_IR_AAM',
#      None,
#      'planes.Mirage_F1M_EE.Pylon6.Mk_83___1000lb_GP_Bomb_LD',
#      'planes.Mirage_F1M_EE.Pylon6.Mk_83___1000lb_GP_Bomb_LD',
#      'planes.Mirage_F1M_EE.Pylon6.Mk_83___1000lb_GP_Bomb_LD',
#      None,
#      'planes.Tornado_IDS.Pylon3.AIM_9P_Sidewinder_IR_AAM']}}],
#  'F-14A-135-GR': [{'type': 'F-14A-135-GR',
#    'payload': {'pylons': ['planes.F_14B.Pylon10.LAU_138_AIM_9L',
#      'planes.F_14B.Pylon9.AIM_7F_',
#      'planes.F_14B.Pylon8.Fuel_tank_300_gal_',
#      'planes.F_14B.Pylon7.MAK79_4_Mk_82',
#      'planes.F_14B.Pylon5.MAK79_3_Mk_82',
#      'planes.F_14B.Pylon6.MAK79_3_Mk_82_',
#      'planes.F_14B.Pylon7.MAK79_4_Mk_82',
#      'planes.F_14B.Pylon8.Fuel_tank_300_gal_',
#      'planes.F_14B.Pylon9.AIM_7F_',
#      'planes.F_14B.Pylon10.LAU_138_AIM_9L']}}],
#  'Mirage-F1CT': [{'type': 'Mirage-F1CT',
#    'payload': {'pylons': ['planes.Mirage_F1M_EE.Pylon7.R550_Magic_1_IR_AAM',
#      'planes.Mirage_F1M_EE.Pylon6.SAMP_400___400_kg_GP_Bomb_LD',
#      'planes.Mirage_F1M_EE.Pylon6.SAMP_400___400_kg_GP_Bomb_LD',
#      'planes.Mirage_F1M_EE.Pylon4.CLB_4___4_x_SAMP_400___400_kg_GP_Bomb_LD',
#      'planes.Mirage_F1M_EE.Pylon6.SAMP_400___400_kg_GP_Bomb_LD',
#      'planes.Mirage_F1M_EE.Pylon6.SAMP_400___400_kg_GP_Bomb_LD',
#      'planes.Mirage_F1M_EE.Pylon7.R550_Magic_1_IR_AAM']}}],
#  'Mirage-F1EE': [{'type': 'Mirage-F1EE',
#    'payload': {'pylons': ['planes.Mirage_F1M_EE.Pylon7.R550_Magic_1_IR_AAM',
#      'planes.Mirage_F1M_EE.Pylon6.SAMP_400___400_kg_GP_Bomb_LD',
#      'planes.Mirage_F1M_EE.Pylon5.PTB_1200_F1',
#      'planes.Mirage_F1M_EE.Pylon4.CLB_4___4_x_SAMP_400___400_kg_GP_Bomb_LD',
#      'planes.Mirage_F1M_EE.Pylon5.PTB_1200_F1',
#      'planes.Mirage_F1M_EE.Pylon6.SAMP_400___400_kg_GP_Bomb_LD',
#      'planes.Mirage_F1M_EE.Pylon7.R550_Magic_1_IR_AAM']}}],
#  'Su-17M4': [{'type': 'Su-17M4',
#    'payload': {'pylons': ['planes.Su_25TM.Pylon9.Kh_25MP__AS_12_Kegler____320kg__ARM__Pas_Rdr',
#      'planes.Su_24MR.Pylon1.APU_60_1M_with_R_60M__AA_8_Aphid_B____IR_AAM_',
#      'planes.Su_25TM.Pylon9.Kh_25MP__AS_12_Kegler____320kg__ARM__Pas_Rdr',
#      'planes.Su_17M4.Pylon5.Fuel_tank_800L',
#      'planes.Su_17M4.Pylon5.Fuel_tank_800L',
#      'planes.Su_25TM.Pylon9.Kh_25MP__AS_12_Kegler____320kg__ARM__Pas_Rdr',
#      'planes.Su_24MR.Pylon1.APU_60_1M_with_R_60M__AA_8_Aphid_B____IR_AAM_',
#      'planes.Su_25TM.Pylon9.Kh_25MP__AS_12_Kegler____320kg__ARM__Pas_Rdr']}},
#   {'type': 'Su-17M4',
#    'payload': {'pylons': ['planes.Su_17M4.Pylon8.MBD3_U4T_with_4_x_FAB_250___250kg_GP_Bombs_LD',
#      'planes.Su_24MR.Pylon1.APU_60_1M_with_R_60M__AA_8_Aphid_B____IR_AAM_',
#      'planes.Su_25TM.Pylon9.UB_32A___32_x_UnGd_Rkts__57_mm_S_5KO_HEAT_Frag',
#      'planes.Su_17M4.Pylon5.Fuel_tank_800L',
#      'planes.Su_17M4.Pylon5.Fuel_tank_800L',
#      'planes.Su_25TM.Pylon9.UB_32A___32_x_UnGd_Rkts__57_mm_S_5KO_HEAT_Frag',
#      'planes.Su_24MR.Pylon1.APU_60_1M_with_R_60M__AA_8_Aphid_B____IR_AAM_',
#      'planes.Su_17M4.Pylon8.MBD3_U4T_with_4_x_FAB_250___250kg_GP_Bombs_LD']}}],
#  'Su-25': [{'type': 'Su-25',
#    'payload': {'pylons': ['planes.Su_25TM.Pylon11.R_60M__AA_8_Aphid_B____IR_AAM',
#      'planes.Su_34.Pylon9.FAB_500_M_62___500kg_GP_Bomb_LD',
#      'planes.Su_34.Pylon9.FAB_500_M_62___500kg_GP_Bomb_LD',
#      'planes.Su_34.Pylon9.FAB_500_M_62___500kg_GP_Bomb_LD',
#      'planes.Su_34.Pylon9.FAB_500_M_62___500kg_GP_Bomb_LD',
#      'planes.Su_34.Pylon9.FAB_500_M_62___500kg_GP_Bomb_LD',
#      'planes.Su_34.Pylon9.FAB_500_M_62___500kg_GP_Bomb_LD',
#      'planes.Su_34.Pylon9.FAB_500_M_62___500kg_GP_Bomb_LD',
#      'planes.Su_34.Pylon9.FAB_500_M_62___500kg_GP_Bomb_LD',
#      'planes.Su_25TM.Pylon11.R_60M__AA_8_Aphid_B____IR_AAM']}},
#   {'type': 'Su-25',
#    'payload': {'pylons': ['planes.Su_25TM.Pylon11.R_60M__AA_8_Aphid_B____IR_AAM',
#      'planes.Su_34.Pylon9.FAB_250_M62___250_kg_GP_Bomb_LD',
#      'planes.Su_34.Pylon9.B_8M1___20_x_UnGd_Rkts__80_mm_S_8KOM_HEAT_Frag',
#      'planes.Su_34.Pylon9.B_8M1___20_x_UnGd_Rkts__80_mm_S_8KOM_HEAT_Frag',
#      'planes.Su_25TM.Pylon8.SPPU_22_1___2_x_23mm__GSh_23L_Autocannon_Pod',
#      'planes.Su_25TM.Pylon8.SPPU_22_1___2_x_23mm__GSh_23L_Autocannon_Pod',
#      'planes.Su_34.Pylon9.B_8M1___20_x_UnGd_Rkts__80_mm_S_8KOM_HEAT_Frag',
#      'planes.Su_34.Pylon9.B_8M1___20_x_UnGd_Rkts__80_mm_S_8KOM_HEAT_Frag',
#      'planes.Su_34.Pylon9.FAB_250_M62___250_kg_GP_Bomb_LD',
#      'planes.Su_25TM.Pylon11.R_60M__AA_8_Aphid_B____IR_AAM']}}],
#  'MiG-27K': [{'type': 'MiG-27K',
#    'payload': {'pylons': [None,
#      'planes.Su_25TM.Pylon9.Kh_25MP__AS_12_Kegler____320kg__ARM__Pas_Rdr',
#      'planes.Su_24MR.Pylon1.APU_60_2M_with_2_x_R_60M__AA_8_Aphid_B____IR_AAM__',
#      'planes.Su_34.Pylon9.RBK_250___42_x_PTAB_2_5M__250kg_CBU_Medium_HEAT_AP',
#      None,
#      'planes.Su_34.Pylon9.RBK_250___42_x_PTAB_2_5M__250kg_CBU_Medium_HEAT_AP',
#      'planes.MiG_31.Pylon6.APU_60_2M_with_2_x_R_60M__AA_8_Aphid_B____IR_AAM___',
#      'planes.Su_25TM.Pylon9.Kh_25MP__AS_12_Kegler____320kg__ARM__Pas_Rdr']}}],
#  'F-5E': [{'type': 'F-5E',
#    'payload': {'pylons': ['planes.Tornado_IDS.Pylon3.AIM_9P_Sidewinder_IR_AAM',
#      'planes.Tornado_IDS.Pylon8.Mk_82___500lb_GP_Bomb_LD',
#      'planes.Tornado_IDS.Pylon8.Mk_82___500lb_GP_Bomb_LD',
#      'planes.F_5E_3_FC.Pylon4._5_x_Mk_82___500lb_GP_Bombs_LD',
#      'planes.Tornado_IDS.Pylon8.Mk_82___500lb_GP_Bomb_LD',
#      'planes.Tornado_IDS.Pylon8.Mk_82___500lb_GP_Bomb_LD',
#      'planes.Tornado_IDS.Pylon3.AIM_9P_Sidewinder_IR_AAM']}}],
#  'L-39ZA': [{'type': 'L-39ZA',
#    'payload': {'pylons': ['planes.Su_34.Pylon9.FAB_250_M62___250_kg_GP_Bomb_LD',
#      'planes.Su_34.Pylon9.FAB_250_M62___250_kg_GP_Bomb_LD',
#      None,
#      'planes.Su_34.Pylon9.FAB_250_M62___250_kg_GP_Bomb_LD',
#      'planes.Su_34.Pylon9.FAB_250_M62___250_kg_GP_Bomb_LD']}}],
#  'Su-24M': [{'type': 'Su-24M',
#    'payload': {'pylons': ['planes.Su_24MR.Pylon1.APU_60_1M_with_R_60M__AA_8_Aphid_B____IR_AAM_',
#      'planes.Su_25TM.Pylon9.Kh_25MP__AS_12_Kegler____320kg__ARM__Pas_Rdr',
#      None,
#      None,
#      'planes.Su_24MR.Pylon5.Fuel_tank_2000L',
#      None,
#      'planes.Su_25TM.Pylon9.Kh_25MP__AS_12_Kegler____320kg__ARM__Pas_Rdr',
#      'planes.Su_24MR.Pylon1.APU_60_1M_with_R_60M__AA_8_Aphid_B____IR_AAM_']}},
#   {'type': 'Su-24M',
#    'payload': {'pylons': ['planes.Su_24MR.Pylon1.APU_60_1M_with_R_60M__AA_8_Aphid_B____IR_AAM_',
#      'planes.Su_34.Pylon9.O_25___1_x_UnGd_Rkts__340_mm_S_25_OFM_Hardened_Target_Penetrator',
#      'planes.Su_34.Pylon9.FAB_500_M_62___500kg_GP_Bomb_LD',
#      None,
#      'planes.Su_24MR.Pylon5.Fuel_tank_2000L',
#      'planes.Su_34.Pylon9.FAB_500_M_62___500kg_GP_Bomb_LD',
#      'planes.Su_34.Pylon9.O_25___1_x_UnGd_Rkts__340_mm_S_25_OFM_Hardened_Target_Penetrator',
#      'planes.Su_24MR.Pylon1.APU_60_1M_with_R_60M__AA_8_Aphid_B____IR_AAM_']}}]}

# %%
print("✈️ Extracting plane templates...")
blue_map = dcs_util.extract_plane_templates(coldwar_mission_data, dcs_util.plane_mission_types, "blue")
red_map = dcs_util.extract_plane_templates(coldwar_mission_data, dcs_util.plane_mission_types, "red")
# Out:
# ✈️ Extracting plane templates...

# %%
dcs_util.apply_sample_templates(mission_data, blue_map, red_map)

mod_df = dcs_util.get_planes(mission_data)
mod_df[(mod_df['Skill']!='Client') & (mod_df['Side']=='Red')]
# Out:
# ✅ Modified 158 unit(s) based on sample maps.
#     Side               Group Name                  Unit Name  Unit Type  \
# 123  Red      offmap-supply-red-1      offmap-supply-red-1-1     An-26B
# 124  Red      offmap-supply-red-2      offmap-supply-red-2-1     An-26B
# 125  Red      offmap-supply-red-3      offmap-supply-red-3-1     An-26B
# 126  Red        beslan-strike-red       nalchik-sead-red-1-2  MiG-21Bis
# 127  Red      beslan-strike-red-1      beslan-strike-red-1-1      Su-25
# ..   ...                      ...                        ...        ...
# 210  Red  mineralnye-strike-red-1  mineralnye-strike-red-1-3  MiG-23MLD
# 211  Red  mineralnye-strike-red-1  mineralnye-strike-red-1-1  MiG-23MLD
# 212  Red  mineralnye-strike-red-1  mineralnye-strike-red-1-2  MiG-23MLD
# 213  Red    mineralnye-patrol-red     mineralnye-cas-red-1-2  MiG-21Bis
# 214  Red    mineralnye-patrol-red     mineralnye-cas-red-1-3  MiG-21Bis
#
#          Skill        Livery ID  \
# 123       High     RF Air Force
# 124       High     RF Air Force
# 125       High     RF Air Force
# 126  Excellent             None
# 127  Excellent             None
# ..         ...              ...
# 210  Excellent             None
# 211  Excellent             None
# 212  Excellent             None
# 213  Excellent  afghanistan (1)
# 214  Excellent  afghanistan (1)
#
#                                          Weapons CLSID  \
# 123
# 124
# 125
# 126  {R-60M}, {37DCC01E-9E02-432F-B61D-10C166CA2798...
# 127  {682A481F-0CB5-4693-A382-D00DD4A156D7}, {38587...
# ..                                                 ...
# 210  <CLEAN>, {6980735A-44CC-4BB9-A1B5-591532F1DC69...
# 211  <CLEAN>, {6980735A-44CC-4BB9-A1B5-591532F1DC69...
# 212  <CLEAN>, {6980735A-44CC-4BB9-A1B5-591532F1DC69...
# 213  {R-3R}, {R-60 2L}, {PTB_800_MIG21}, {R-60 2R},...
# 214  {R-3R}, {R-60 2L}, {PTB_800_MIG21}, {R-60 2R},...
#
#                                           Weapon Names  \
# 123
# 124
# 125
# 126  APU-60-1M with R-60M (AA-8 Aphid-B) - IR AAM, ...
# 127  R-60M (AA-8 Aphid-B) - IR AAM, APU-68 - S-24B ...
# ..                                                 ...
# 210  Unknown Weapon, R-24T (AA-7 Apex IR) - Infra R...
# 211  Unknown Weapon, R-24T (AA-7 Apex IR) - Infra R...
# 212  Unknown Weapon, R-24T (AA-7 Apex IR) - Infra R...
# 213  APU-13U-2 with R-3R (AA-2 Atoll-C) - Semi Acti...
# 214  APU-13U-2 with R-3R (AA-2 Atoll-C) - Semi Acti...
#
#      Total Weapon Weight (kg)
# 123                      0.00
# 124                      0.00
# 125                      0.00
# 126                   1867.00
# 127                   2039.00
# ..                        ...
# 210                   1700.00
# 211                   1700.00
# 212                   1700.00
# 213                   1246.28
# 214                   1246.28
#
# [92 rows x 9 columns]

# %%
# Update Mission File
